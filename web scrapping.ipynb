# %%
# Installing BeautifulSoup

! pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\dell\anaconda\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\anaconda\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)

# %%
# Loading required libraries

import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup

# %%
# Identify the URL

URL = 'https://www.cars24.com/buy-used-cars-hyderabad/?itm_source=Cars24Website&itm_medium=sticky_header'

# %%
# Loading the WebPage in Memory using requests library

page = requests.get(URL)

# %%
# Check the Status Code of the Page

page.status_code
# Out:
# 200

# %%
# Extracting the HTML Code of the WebPage

htmlCode = page.text

# %%
htmlCode
# Out:
# '<!DOCTYPE html>\n\n<html lang="en">\n\n<head>\n    <link rel="preconnect" href="//www.googleoptimize.com" />\n    <link rel="preconnect" href="//www.googletagmanager.com" />\n    <link rel="preconnect" href="//www.google-analytics.com" />\n    <link rel="preconnect" href="//connect.facebook.net" />\n    <link rel="preconnect" href="//cdn.jsdelivr.net" />\n    <link rel="preconnect" href="//widgets.getsitecontrol.com" />\n    <link rel="preconnect" href="//s.yimg.com" />\n    <link rel="preconnect" href="//www.googleadservices.com" />\n    <link rel="preconnect" href="//d2r1yp2w7bby2u.cloudfront.net" /><meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" />\n  <meta property="fb:app_id" content="697234207046254" /><!--scripts from helmet--><link data-react-helmet="true" href="https://www.cars24.com/buy-used-cars-hyderabad/" rel="canonical"/><link data-react-helmet="true" href="https://www.cars24.com/buy-used-cars-hyderabad/amp/" rel="amphtml"/><script data-react-helmet="true" type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n          new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n          j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n          \'//www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n          })(window,document,\'script\',\'dataLayer\',\'GTM-P3C9RJ\');</script><script data-react-helmet="true" type="text/javascript">(function(a,s,y,n,c,h,i,d,e){s.className+=\' \'+y;h.start=1*new Date;\n    h.end=i=function(){s.className=s.className.replace(RegExp(\' ?\'+y),\'\')};\n    (a[n]=a[n]||[]).hide=h;setTimeout(function()\n    {i();h.end=null},c);h.timeout=c;\n    })(window,document.documentElement,\'async-hide\',\'dataLayer\',4000,{\'GTM-NFJTXNR\':true});</script><script data-react-helmet="true" type="text/javascript">(function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function()\n    { (i[r].q=i[r].q||[]).push(arguments)}\n    ,i[r].l=1*new Date();a=s.createElement(o),\n    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'https://www.google-analytics.com/analytics.js\',\'ga\');\n    ga(\'create\', \'UA-65843992-1\', \'auto\');ga(\'require\', \'GTM-NFJTXNR\');</script><script data-react-helmet="true" type="application/ld+json">{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":"1","item":{"@id":"https://www.cars24.com","name":"Home"}},{"@type":"ListItem","position":"2","item":{"@id":"https://www.cars24.com/buy-used-cars/","name":"Buy Used Cars"}},{"@type":"ListItem","position":"3","item":{"@id":"https://www.cars24.com/buy-used-cars-hyderabad/","name":"Hyderabad"}}]}</script><script data-react-helmet="true" type="application/ld+json">{"@context":"https://schema.org","@type":"FAQPage","mainEntity":[{"@type":"Question","name":"How many second hand cars are available in Hyderabad?","acceptedAnswer":{"@type":"Answer","text":"41 used cars are available in Hyderabad of popular brands like <a href=\\"https://www.cars24.com/buy-used-maruti-cars-hyderabad\\">Maruti Suzuki</a>, <a href=\\"https://www.cars24.com/buy-used-hyundai-cars-hyderabad\\">Hyundai</a>, <a href=\\"https://www.cars24.com/buy-used-honda-cars-hyderabad\\">Honda</a> & more"}},{"@type":"Question","name":"What are the most popular brands available for 2nd hand cars in Hyderabad?","acceptedAnswer":{"@type":"Answer","text":"CARS24 has a wide inventory of all brands including <a href=\\"https://www.cars24.com/buy-used-maruti-cars-hyderabad\\">Maruti Suzuki</a>, <a href=\\"https://www.cars24.com/buy-used-hyundai-cars-hyderabad\\">Hyundai</a>, <a href=\\"https://www.cars24.com/buy-used-honda-cars-hyderabad\\">Honda</a> & more. Find the best second hand car in Hyderabad of your choice on CARS24."}},{"@type":"Question","name":"What will b ...

# %%
soup=BeautifulSoup(htmlCode)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="//www.googleoptimize.com" rel="preconnect"/>
#   <link href="//www.googletagmanager.com" rel="preconnect"/>
#   <link href="//www.google-analytics.com" rel="preconnect"/>
#   <link href="//connect.facebook.net" rel="preconnect"/>
#   <link href="//cdn.jsdelivr.net" rel="preconnect"/>
#   <link href="//widgets.getsitecontrol.com" rel="preconnect"/>
#   <link href="//s.yimg.com" rel="preconnect"/>
#   <link href="//www.googleadservices.com" rel="preconnect"/>
#   <link href="//d2r1yp2w7bby2u.cloudfront.net" rel="preconnect"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#   <meta content="697234207046254" property="fb:app_id"/>
#   <!--scripts from helmet-->
#   <link data-react-helmet="true" href="https://www.cars24.com/buy-used-cars-hyderabad/" rel="canonical"/>
#   <link data-react-helmet="true" href="https://www.cars24.com/buy-used-cars-hyderabad/amp/" rel="amphtml"/>
#   <script data-react-helmet="true" type="text/javascript">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#           new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#           j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#           '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer','GTM-P3C9RJ');
#   </script>
#   <script data-react-helmet="true" type="text/javascript">
#    (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#     h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#     (a[n]=a[n]||[]).hide=h;setTimeout(function()
#     {i();h.end=null},c);h.timeout=c;
#     })(window,document.documentElement,'async-hide','dataLayer',4000,{'GTM-NFJTXNR':true});
#   </script>
#   <script data-react-helmet="true" type="text/javascript">
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function()
#     { (i[r].q=i[r].q||[]).push(arguments)}
#     ,i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#     ga('create', 'UA-65843992-1', 'auto');ga('require', 'GTM-NFJTXNR');
#   </script>
#   <script data-react-helmet="true" type="application/ld+json">
#    {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":"1","item":{"@id":"https://www.cars24.com","name":"Home"}},{"@type":"ListItem","position":"2","item":{"@id":"https://www.cars24.com/buy-used-cars/","name":"Buy Used Cars"}},{"@type":"ListItem","position":"3","item":{"@id":"https://www.cars24.com/buy-used-cars-hyderabad/","name":"Hyderabad"}}]}
#   </script>
#   <script data-react-helmet="true" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"FAQPage","mainEntity":[{"@type":"Question","name":"How many second hand cars are available in Hyderabad?","acceptedAnswer":{"@type":"Answer","text":"41 used cars are available in Hyderabad of popular brands like <a href=\"https://www.cars24.com/buy-used-maruti-cars-hyderabad\">Maruti Suzuki</a>, <a href=\"https://www.cars24.com/buy-used-hyundai-cars-hyderabad\">Hyundai</a>, <a href=\"https://www.cars24.com/buy-used-honda-cars-hyderabad\">Honda</a> & more"}},{"@type":"Question","name":"What are the most popular brands available for 2nd hand cars in Hyderabad?","acceptedAnswer":{"@type":"Answer","text":"CARS24 has a wide inventory of all brands including <a href=\"https://www.cars24.com/buy-used-maruti-cars-hyderabad\">Maruti Suzuki</a>, <a href=\"https://www.cars24.com/buy-used-hyundai-cars-hyderabad\">Hyundai</a>, <a href=\"https://www.cars24.com/buy-used-honda-cars-hyderabad\">Honda</a> & more. Find the best second hand car in Hyderabad of your choice on CARS24."}},{"@type":"Question","name":"What will be the starting price of an old car in Hyderabad?","acceptedAnswer":{"@type":"Answer","text":"The starting price of a used car in Hyderabad is Rs. ₹1,00,000."}},{"@type":"Question","name":"What body types are available for 2nd hand cars in Hyderabad?","acceptedAnswer":{"@type":"Answer","text":"Used cars in Hyderabad are available from every segment, be it <a href=\"https://www.cars24.com/buy-used-hatchback-cars-hyderabad\">Hatchback</a>, <a href=\"https://www.cars24.com/buy-used-sedan-cars-hyderabad\">Sedan</a>, <a href=\"https://www.cars24.com/buy-used-suv-cars-hyderabad\">SUV</a>."}},{"@type":"Question","name":"Can I buy used cars online at CARS24 in Hyderabad?","acceptedAnswer":{"@type":"Answer","text":"Of Course yes, you can buy used cars online in Hyderabad from CARS24. You can find thousands of quality second hand cars for sale on our website/app that can be bought at the click of a button & delivered to your doorstep anywhere in Hyderabad"}},{"@type":"Question","name":"What to check before buying a second hand car in Hyderabad?","acceptedAnswer":{"@type":"Answer","text":"Important things to check  before buying a second hand car in Hyderabad are:<ul><li><strong>Source:</strong> Buying a car from a trusted source is important to make sure the car is in the exact condition as stated & also to deal with any post sale related issues.</li><li><strong>Condition:</strong> Ensure the car is non-accidental & does not have any structural damage. We use a 140 point check to make sure every car we sell is in top condition.</li><li><strong>Age:</strong> Buying a used car that is very old can lead to problems like expensive maintenance costs and scarcity of spare parts. A three to five year old car should be an ideal buy,</li><li><strong>Car Documents:</strong> Verification of vehicle documents like Registration Certificate (RC), Insurance & PUC is very important. Also ensure the car is not under loan (hypothecated), there are no traffic challans or any legal issues with it.</li><li><strong>Certified or Not:</strong> Certified used cars come with warranty and are refurbished to as good as new to protect buyers from unforeseen repair & maintenance cost.</li></ul>"}},{"@type":"Question","name":"Where can I buy used cars in Hyderabad?","acceptedAnswer":{"@type":"Answer","text":"You can buy used cars in Hyderabad from Cars24. Visit our website, book the car of your choice & get it delivered to your home."}},{"@type":"Question","name":"How can I check a second hand car in Hyderabad?","acceptedAnswer":{"@type":"Answer","text":"You can check second hand cars in Hyderabad using conventional & time consuming buying methods like classified, dealers etc. CARS24 brings you a virtual showroom experience at your fingertips using 360 view. You can check multiple cars for sale in minutes and buy one from the comfort of your couch. We’ll deliver the car anywhere in Hyderabad"}}]}
#   </script>
#   <meta content="zedoskz9z2kgib48fyopeheaincj11" data-react-helmet="true" name="facebook-domain-verification"/>
#   <meta content="INDEX,FOLLOW" data-react-helmet="true" name="ROBOTS"/>
#   <meta content="Used Cars in Hyderabad - Second Hand Cars in Hyderabad for Sale" data-react-helmet="true" name="title"/>
#   <meta content="Used cars in Hyderabad for Sale - Cars24 offers 100% verified second hand cars in Hyderabad. Avail old cars at best price along with Easy Finance &amp; RC Transfer." data-react-helmet="true" name="description"/>
#   <meta content="Buy used cars in Hyderabad, buy used cars online in Hyderabad, Used Cars Online in Hyderabad, Second Hand Cars in Hyderabad, Second Hand Cars Online in Hyderabad, Buy Second hand cars online in Hyderabad, Certified Used Cars in Hyderabad, Pre-owned cars online in Hyderabad" data-react-helmet="true" name="keywords"/>
#   <meta content="Used Cars in Hyderabad - Second Hand Cars in Hyderabad for Sale" data-react-helmet="true" property="og:title"/>
#   <meta content="Used cars in Hyderabad for Sale - Cars24 offers 100% verified second hand cars in Hyderabad. Avail old cars at best price along with Easy Finance &amp; RC Transfer." data-react-helmet="true" property="og:description"/>
#   <meta content="https://www.cars24.com/buy-used-cars-hyderabad/" data-react-helmet="true" property="og:url"/>
#   <meta content="website" data-react-helmet="true" property="og:type"/>
#   <meta content="Cars24" data-react-helmet="true" property="og:site_name"/>
#   <meta content="https://static.cars24.com/cars24/images/cars-logo.png?v=1" data-react-helmet="true" property="og:image"/>
#   <title data-react-helmet="true">
#    Used Cars in Hyderabad - Second Hand Cars in Hyderabad for Sale
#   </title>
#   <style>
#    :root{--blue:#007bff;--indigo:#6610f2;--purple:#6f42c1;--pink:#e83e8c;--red:#dc3545;--orange:#fd7e14;--yellow:#ffc107;--green:#28a745;--teal:#20c997;--cyan:#17a2b8;--white:#fff;--gray:#6c757d;--gray-dark:#343a40;--primary:#007bff;--secondary:#6c757d;--success:#28a745;--info:#17a2b8;--warning:#ffc107;--danger:#dc3545;--light:#f8f9fa;--dark:#343a40;--breakpoint-xs:0;--breakpoint-sm:576px;--breakpoint-md:768px;--breakpoint-lg:992px;--breakpoint-xl:1200px;--font-family-sans-serif:-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji";--font-family-monospace:SFMono-Regular,Menlo,Monaco,Consolas,"Liberation Mono","Courier New",monospace}*,::after,::before{box-sizing:border-box}html{font-family:sans-serif;line-height:1.15;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%;-ms-overflow-style:scrollbar;-webkit-tap-highlight-color:transparent}@-ms-viewport{width:device-width}article,aside,figcaption,figure,footer,header,hgroup,main,nav,section{display:block}body{margin:0;font-family:-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji";font-size:1rem;font-weight:400;line-height:1.5;color:#212529;text-align:left;background-color:#fff}[tabindex="-1"]:focus{outline:0!important}hr{box-sizing:content-box;height:0;overflow:visible}h1,h2,h3,h4,h5,h6{margin-top:0;margin-bottom:.5rem}p{margin-top:0;margin-bottom:1rem}abbr[data-original-title],abbr[title]{text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted;cursor:help;border-bottom:0}address{margin-bottom:1rem;font-style:normal;line-height:inherit}dl,ol,ul{margin-top:0;margin-bottom:1rem}ol ol,ol ul,ul ol,ul ul{margin-bottom:0}dt{font-weight:700}dd{margin-bottom:.5rem;margin-left:0}blockquote{margin:0 0 1rem}dfn{font-style:italic}b,strong{font-weight:bolder}small{font-size:80%}sub,sup{position:relative;font-size:75%;line-height:0;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}a{color:#007bff;text-decoration:none;background-color:transparent;-webkit-text-decoration-skip:objects}a:hover{color:#0056b3;text-decoration:underline}a:not([href]):not([tabindex]){color:inherit;text-decoration:none}a:not([href]):not([tabindex]):focus,a:not([href]):not([tabindex]):hover{color:inherit;text-decoration:none}a:not([href]):not([tabindex]):focus{outline:0}code,kbd,pre,samp{font-family:SFMono-Regular,Menlo,Monaco,Consolas,"Liberation Mono","Courier New",monospace;font-size:1em}pre{margin-top:0;margin-bottom:1rem;overflow:auto;-ms-overflow-style:scrollbar}figure{margin:0 0 1rem}img{vertical-align:middle;border-style:none}svg{overflow:hidden;vertical-align:middle}table{border-collapse:collapse}caption{padding-top:.75rem;padding-bottom:.75rem;color:#6c757d;text-align:left;caption-side:bottom}th{text-align:inherit}label{display:inline-block;margin-bottom:.5rem}button{border-radius:0}button:focus{outline:1px dotted;outline:5px auto -webkit-focus-ring-color}button,input,optgroup,select,textarea{margin:0;font-family:inherit;font-size:inherit;line-height:inherit}button,input{overflow:visible}button,select{text-transform:none}[type=reset],[type=submit],button,html [type=button]{-webkit-appearance:button}[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner{padding:0;border-style:none}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=date],input[type=datetime-local],input[type=month],input[type=time]{-webkit-appearance:listbox}textarea{overflow:auto;resize:vertical}fieldset{min-width:0;padding:0;margin:0;border:0}legend{display:block;width:100%;max-width:100%;padding:0;margin-bottom:.5rem;font-size:1.5rem;line-height:inherit;color:inherit;white-space:normal}progress{vertical-align:baseline}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-s ...
#   </style>
#   <script>
#    window.undefined_config = window.undefined_config || {};
# window.undefined_config.ui = {"demo":"hello from ui config"};
#   </script>
#   <link data-chunk="desktop" href="https://www.cars24.com/js/desktop.style.63d47d4758a8cf1442b5.css" rel="stylesheet"/>
#   <link data-chunk="pages-desktop-car-listing" href="https://www.cars24.com/js/pages-desktop-car-listing.style.94a687cc5f413fafd275.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="js-content">
#    <div class="Ye5SB">
#     <div class="_5mrX0">
#      <div class="container">
#       <ul class="float-right _11_An">
#        <li>
#         <a href="https://www.cars24.com/rc-transfer">
#          RC Transfer Status
#         </a>
#        </li>
#        <li>
#         <a href="https://www.cars24.com/become-our-partner">
#          Become Our Partner
#         </a>
#        </li>
#        <li>
#         <a href="https://www.cars24.com/faq">
#          FAQs
#         </a>
#        </li>
#        <li class="_2Cpir">
#         <a class="_108SD" href="tel:18002585656 ">
#          1800-258-5656
#         </a>
#         <small>
#          8am - 10pm
#         </small>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="_1Nfgw">
#      <div class="container">
#       <div class="row">
#        <div class="col-md-3 _2VocW">
#         <a class="d-inline-block XSgwF" href="/">
#          <img alt="logo" src="https://static.cars24.com/cars24/images/cars-logo.png?v=1"/>
#         </a>
#         <p class="_1OR7d">
#          Select City
#          <span>
#           <img src="https://www.cars24.com/js/00812dfff0fe0ac355de4e741fa2cd53.svg" style="transform:rotate(180deg)"/>
#          </span>
#         </p>
#        </div>
#        <div class="col-md-9">
#         <div class="float-left PBL2-">
#          <div class="css-1pcexqc-container search-select-container auto-complete-search">
#           <div class="css-bg1rzq-control search-select__control">
#            <div class="css-1hwfws3 search-select__value-container">
#             <div class="css-151xaom-placeholder search-select__placeholder">
#              Find your dream car with us
#             </div>
#             <div class="css-1g6gooi">
#              <div class="search-select__input" style="display:inline-block">
#               <input aria-autocomplete="list" autocapitalize="none" autocomplete="off" autocorrect="off" id="react-select-9679-input" spellcheck="false" style="box-sizing:content-box;width:1px;label:input;background:0;border:0;font-size:inherit;opacity:1;outline:0;padding:0;color:inherit" tabindex="0" type="text" value=""/>
#               <div style="position:absolute;top:0;left:0;visibility:hidden;height:0;overflow:scroll;white-space:pre">
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="css-1wy0on6 search-select__indicators">
#             <span class="css-bgvzuu-indicatorSeparator search-select__indicator-separator">
#             </span>
#             <div aria-hidden="true" class="css-16pqwjk-indicatorContainer search-select__indicator search-select__dropdown-indicator">
#              <svg aria-hidden="true" class="css-19bqh2r" focusable="false" height="20" viewbox="0 0 20 20" width="20">
#               <path d="M4.516 7.548c0.436-0.446 1.043-0.481 1.576 0l3.908 3.747 3.908-3.747c0.533-0.481 1.141-0.446 1.574 0 0.436 0.445 0.408 1.197 0 1.615-0.406 0.418-4.695 4.502-4.695 4.502-0.217 0.223-0.502 0.335-0.787 0.335s-0.57-0.112-0.789-0.335c0 0-4.287-4.084-4.695-4.502s-0.436-1.17 0-1.615z">
#               </path>
#              </svg>
#             </div>
#            </div>
#           </div>
#          </div>
#          <label class="sBpaf">
#          </label>
#         </div>
#         <ul class="float-right _1yq3e">
#          <li class="uiu4E">
#           <a href="/buy-used-cars/">
#            Buy Used Cars
#           </a>
#           <ul class="_3Qfsi">
#            <p>
#             Popular Cities
#            </p>
#            <li>
#             <span>
#              Used cars in
#              <!-- -->
#              Bengaluru
#             </span>
#             <ul>
#              <p>
#               Popular Cars
#              </p>
#              <li>
#               <a href="https://www.cars24.com/buy-used-hyundai-cars-bengaluru/">
#                Used
#                <!-- -->
#                Hyundai
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-renault-cars-bengaluru/">
#                Used
#                <!-- -->
#                Renault
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-mahindra-cars-bengaluru/">
#                Used
#                <!-- -->
#                Mahindra
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-toyota-cars-bengaluru/">
#                Used
#                <!-- -->
#                Toyota
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-audi-cars-bengaluru/">
#                Used
#                <!-- -->
#                Audi
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-honda-cars-bengaluru/">
#                Used
#                <!-- -->
#                Honda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-maruti-cars-bengaluru/">
#                Used
#                <!-- -->
#                Maruti
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-tata-cars-bengaluru/">
#                Used
#                <!-- -->
#                Tata
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-ford-cars-bengaluru/">
#                Used
#                <!-- -->
#                Ford
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-skoda-cars-bengaluru/">
#                Used
#                <!-- -->
#                Skoda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-cars-bengaluru/">
#                All used cars in
#                <!-- -->
#                Bengaluru
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li>
#             <span>
#              Used cars in
#              <!-- -->
#              Chennai
#             </span>
#             <ul>
#              <p>
#               Popular Cars
#              </p>
#              <li>
#               <a href="https://www.cars24.com/buy-used-hyundai-cars-chennai/">
#                Used
#                <!-- -->
#                Hyundai
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-renault-cars-chennai/">
#                Used
#                <!-- -->
#                Renault
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-mahindra-cars-chennai/">
#                Used
#                <!-- -->
#                Mahindra
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-toyota-cars-chennai/">
#                Used
#                <!-- -->
#                Toyota
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-audi-cars-chennai/">
#                Used
#                <!-- -->
#                Audi
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-honda-cars-chennai/">
#                Used
#                <!-- -->
#                Honda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-maruti-cars-chennai/">
#                Used
#                <!-- -->
#                Maruti
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-tata-cars-chennai/">
#                Used
#                <!-- -->
#                Tata
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-ford-cars-chennai/">
#                Used
#                <!-- -->
#                Ford
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-skoda-cars-chennai/">
#                Used
#                <!-- -->
#                Skoda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-cars-chennai/">
#                All used cars in
#                <!-- -->
#                Chennai
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li>
#             <span>
#              Used cars in
#              <!-- -->
#              New Delhi
#             </span>
#             <ul>
#              <p>
#               Popular Cars
#              </p>
#              <li>
#               <a href="https://www.cars24.com/buy-used-hyundai-cars-new-delhi/">
#                Used
#                <!-- -->
#                Hyundai
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-renault-cars-new-delhi/">
#                Used
#                <!-- -->
#                Renault
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-mahindra-cars-new-delhi/">
#                Used
#                <!-- -->
#                Mahindra
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-toyota-cars-new-delhi/">
#                Used
#                <!-- -->
#                Toyota
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-audi-cars-new-delhi/">
#                Used
#                <!-- -->
#                Audi
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-honda-cars-new-delhi/">
#                Used
#                <!-- -->
#                Honda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-maruti-cars-new-delhi/">
#                Used
#                <!-- -->
#                Maruti
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-tata-cars-new-delhi/">
#                Used
#                <!-- -->
#                Tata
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-ford-cars-new-delhi/">
#                Used
#                <!-- -->
#                Ford
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-skoda-cars-new-delhi/">
#                Used
#                <!-- -->
#                Skoda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-cars-new-delhi/">
#                All used cars in
#                <!-- -->
#                New Delhi
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li>
#             <span>
#              Used cars in
#              <!-- -->
#              Mumbai
#             </span>
#             <ul>
#              <p>
#               Popular Cars
#              </p>
#              <li>
#               <a href="https://www.cars24.com/buy-used-hyundai-cars-mumbai/">
#                Used
#                <!-- -->
#                Hyundai
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-renault-cars-mumbai/">
#                Used
#                <!-- -->
#                Renault
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-mahindra-cars-mumbai/">
#                Used
#                <!-- -->
#                Mahindra
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-toyota-cars-mumbai/">
#                Used
#                <!-- -->
#                Toyota
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-audi-cars-mumbai/">
#                Used
#                <!-- -->
#                Audi
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-honda-cars-mumbai/">
#                Used
#                <!-- -->
#                Honda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-maruti-cars-mumbai/">
#                Used
#                <!-- -->
#                Maruti
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-tata-cars-mumbai/">
#                Used
#                <!-- -->
#                Tata
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-ford-cars-mumbai/">
#                Used
#                <!-- -->
#                Ford
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-skoda-cars-mumbai/">
#                Used
#                <!-- -->
#                Skoda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-cars-mumbai/">
#                All used cars in
#                <!-- -->
#                Mumbai
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li>
#             <span>
#              Used cars in
#              <!-- -->
#              Pune
#             </span>
#             <ul>
#              <p>
#               Popular Cars
#              </p>
#              <li>
#               <a href="https://www.cars24.com/buy-used-hyundai-cars-pune/">
#                Used
#                <!-- -->
#                Hyundai
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-renault-cars-pune/">
#                Used
#                <!-- -->
#                Renault
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-mahindra-cars-pune/">
#                Used
#                <!-- -->
#                Mahindra
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-toyota-cars-pune/">
#                Used
#                <!-- -->
#                Toyota
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-audi-cars-pune/">
#                Used
#                <!-- -->
#                Audi
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-honda-cars-pune/">
#                Used
#                <!-- -->
#                Honda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-maruti-cars-pune/">
#                Used
#                <!-- -->
#                Maruti
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-tata-cars-pune/">
#                Used
#                <!-- -->
#                Tata
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-ford-cars-pune/">
#                Used
#                <!-- -->
#                Ford
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-skoda-cars-pune/">
#                Used
#                <!-- -->
#                Skoda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-cars-pune/">
#                All used cars in
#                <!-- -->
#                Pune
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li>
#             <span>
#              Used cars in
#              <!-- -->
#              Hyderabad
#             </span>
#             <ul>
#              <p>
#               Popular Cars
#              </p>
#              <li>
#               <a href="https://www.cars24.com/buy-used-hyundai-cars-hyderabad/">
#                Used
#                <!-- -->
#                Hyundai
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-renault-cars-hyderabad/">
#                Used
#                <!-- -->
#                Renault
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-mahindra-cars-hyderabad/">
#                Used
#                <!-- -->
#                Mahindra
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-toyota-cars-hyderabad/">
#                Used
#                <!-- -->
#                Toyota
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-audi-cars-hyderabad/">
#                Used
#                <!-- -->
#                Audi
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-honda-cars-hyderabad/">
#                Used
#                <!-- -->
#                Honda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-maruti-cars-hyderabad/">
#                Used
#                <!-- -->
#                Maruti
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-tata-cars-hyderabad/">
#                Used
#                <!-- -->
#                Tata
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-ford-cars-hyderabad/">
#                Used
#                <!-- -->
#                Ford
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-skoda-cars-hyderabad/">
#                Used
#                <!-- -->
#                Skoda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-cars-hyderabad/">
#                All used cars in
#                <!-- -->
#                Hyderabad
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li>
#             <span>
#              Used cars in
#              <!-- -->
#              Kolkata
#             </span>
#             <ul>
#              <p>
#               Popular Cars
#              </p>
#              <li>
#               <a href="https://www.cars24.com/buy-used-hyundai-cars-kolkata/">
#                Used
#                <!-- -->
#                Hyundai
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-renault-cars-kolkata/">
#                Used
#                <!-- -->
#                Renault
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-mahindra-cars-kolkata/">
#                Used
#                <!-- -->
#                Mahindra
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-toyota-cars-kolkata/">
#                Used
#                <!-- -->
#                Toyota
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-audi-cars-kolkata/">
#                Used
#                <!-- -->
#                Audi
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-honda-cars-kolkata/">
#                Used
#                <!-- -->
#                Honda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-maruti-cars-kolkata/">
#                Used
#                <!-- -->
#                Maruti
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-tata-cars-kolkata/">
#                Used
#                <!-- -->
#                Tata
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-ford-cars-kolkata/">
#                Used
#                <!-- -->
#                Ford
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-skoda-cars-kolkata/">
#                Used
#                <!-- -->
#                Skoda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-cars-kolkata/">
#                All used cars in
#                <!-- -->
#                Kolkata
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li>
#             <span>
#              Used cars in
#              <!-- -->
#              Ahmedabad
#             </span>
#             <ul>
#              <p>
#               Popular Cars
#              </p>
#              <li>
#               <a href="https://www.cars24.com/buy-used-hyundai-cars-ahmedabad/">
#                Used
#                <!-- -->
#                Hyundai
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-renault-cars-ahmedabad/">
#                Used
#                <!-- -->
#                Renault
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-mahindra-cars-ahmedabad/">
#                Used
#                <!-- -->
#                Mahindra
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-toyota-cars-ahmedabad/">
#                Used
#                <!-- -->
#                Toyota
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-audi-cars-ahmedabad/">
#                Used
#                <!-- -->
#                Audi
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-honda-cars-ahmedabad/">
#                Used
#                <!-- -->
#                Honda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-maruti-cars-ahmedabad/">
#                Used
#                <!-- -->
#                Maruti
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-tata-cars-ahmedabad/">
#                Used
#                <!-- -->
#                Tata
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-ford-cars-ahmedabad/">
#                Used
#                <!-- -->
#                Ford
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-skoda-cars-ahmedabad/">
#                Used
#                <!-- -->
#                Skoda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-cars-ahmedabad/">
#                All used cars in
#                <!-- -->
#                Ahmedabad
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li>
#             <span>
#              Used cars in
#              <!-- -->
#              Jaipur
#             </span>
#             <ul>
#              <p>
#               Popular Cars
#              </p>
#              <li>
#               <a href="https://www.cars24.com/buy-used-hyundai-cars-jaipur/">
#                Used
#                <!-- -->
#                Hyundai
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-renault-cars-jaipur/">
#                Used
#                <!-- -->
#                Renault
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-mahindra-cars-jaipur/">
#                Used
#                <!-- -->
#                Mahindra
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-toyota-cars-jaipur/">
#                Used
#                <!-- -->
#                Toyota
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-audi-cars-jaipur/">
#                Used
#                <!-- -->
#                Audi
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-honda-cars-jaipur/">
#                Used
#                <!-- -->
#                Honda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-maruti-cars-jaipur/">
#                Used
#                <!-- -->
#                Maruti
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-tata-cars-jaipur/">
#                Used
#                <!-- -->
#                Tata
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-ford-cars-jaipur/">
#                Used
#                <!-- -->
#                Ford
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-skoda-cars-jaipur/">
#                Used
#                <!-- -->
#                Skoda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-cars-jaipur/">
#                All used cars in
#                <!-- -->
#                Jaipur
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li>
#             <span>
#              Used cars in
#              <!-- -->
#              Chandigarh
#             </span>
#             <ul>
#              <p>
#               Popular Cars
#              </p>
#              <li>
#               <a href="https://www.cars24.com/buy-used-hyundai-cars-chandigarh/">
#                Used
#                <!-- -->
#                Hyundai
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-renault-cars-chandigarh/">
#                Used
#                <!-- -->
#                Renault
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-mahindra-cars-chandigarh/">
#                Used
#                <!-- -->
#                Mahindra
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-toyota-cars-chandigarh/">
#                Used
#                <!-- -->
#                Toyota
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-audi-cars-chandigarh/">
#                Used
#                <!-- -->
#                Audi
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-honda-cars-chandigarh/">
#                Used
#                <!-- -->
#                Honda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-maruti-cars-chandigarh/">
#                Used
#                <!-- -->
#                Maruti
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-tata-cars-chandigarh/">
#                Used
#                <!-- -->
#                Tata
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-ford-cars-chandigarh/">
#                Used
#                <!-- -->
#                Ford
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-skoda-cars-chandigarh/">
#                Used
#                <!-- -->
#                Skoda
#                <!-- -->
#                cars
#               </a>
#              </li>
#              <li>
#               <a href="https://www.cars24.com/buy-used-cars-chandigarh/">
#                All used cars in
#                <!-- -->
#                Chandigarh
#               </a>
#              </li>
#             </ul>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="https://www.cars24.com/?itm_source=C2CWebsite&amp;itm_medium=header">
#            Sell Used Car
#           </a>
#          </li>
#          <li class="_3Yddk">
#           <a href="https://www.cars24.com/account/login?redirect_url=https://www.cars24.com">
#            <span class="_2uFuR">
#             <div>
#              <img src="https://www.cars24.com/js/357f7319d654f0c37379df76695abe18.svg"/>
#             </div>
#            </span>
#            <span class="_3iI8y">
#             Login/Sign Up
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="o0pOR">
#      <div class="_1MUBn">
#       <ul class="_3oLON">
#        <li>
#         <a href="https://www.cars24.com">
#          Home
#         </a>
#        </li>
#        <li>
#         <a href="/buy-used-cars/">
#          Used Cars
#         </a>
#        </li>
#        <li>
#         Hyderabad
#        </li>
#       </ul>
#      </div>
#      <div>
#       <div class="row">
#        <div class="col-md-10 d-flex align-items-center">
#         <div class="_2x7Ka">
#          <div class="S3jH2">
#           <div class="css-1pcexqc-container search-select-container auto-complete-search">
#            <div class="css-bg1rzq-control search-select__control">
#             <div class="css-1hwfws3 search-select__value-container">
#              <div class="css-151xaom-placeholder search-select__placeholder">
#               Find your dream car with us
#              </div>
#              <div class="css-1g6gooi">
#               <div class="search-select__input" style="display:inline-block">
#                <input aria-autocomplete="list" autocapitalize="none" autocomplete="off" autocorrect="off" id="react-select-9680-input" spellcheck="false" style="box-sizing:content-box;width:1px;label:input;background:0;border:0;font-size:inherit;opacity:1;outline:0;padding:0;color:inherit" tabindex="0" type="text" value=""/>
#                <div style="position:absolute;top:0;left:0;visibility:hidden;height:0;overflow:scroll;white-space:pre">
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="css-1wy0on6 search-select__indicators">
#              <span class="css-bgvzuu-indicatorSeparator search-select__indicator-separator">
#              </span>
#              <div aria-hidden="true" class="css-16pqwjk-indicatorContainer search-select__indicator search-select__dropdown-indicator">
#               <svg aria-hidden="true" class="css-19bqh2r" focusable="false" height="20" viewbox="0 0 20 20" width="20">
# ...
#            <div class="_3mZ8j">
#             <span class="lazy-load-image-background blur" style="background-image:;background-size:;display:inline-block">
#              <span class="" style="display:inline-block">
#              </span>
#             </span>
#             <noscript>
#              <img alt="Discount" src="https://www.cars24.com/js/0106f02192c4d92b3a05ecf440d6babc.svg"/>
#             </noscript>
#             ₹
#             <!-- -->
#             27,000
#             <!-- -->
#             OFF
#            </div>
#            <span class="lazy-load-image-background blur" style="background-image:;background-size:;display:inline-block">
#             <span class="_2gVj9" style="display:inline-block">
#             </span>
#            </span>
#            <noscript>
#             <img alt="2012 Maruti Alto LXI" class="_2gVj9" src="https://fastly-production.24c.in/inspection-car/appointments/1045616921/spincar/1632738515-cu-2.jpg?w=345&amp;auto=format"/>
#            </noscript>
#           </div>
#           <div class="_1l4fi">
#            <div class="_15rKe">
#             <div class="_1jpRU">
#              <h2 class="_3FpCg">
#               2012 Maruti Alto
#              </h2>
#              <p class="cvakB">
#               LXI
#               <!-- -->
#               <span>
#                Manual
#               </span>
#              </p>
#             </div>
#            </div>
#            <ul class="bVR0c">
#             <li>
#              21,364 km
#             </li>
#             <li>
#              1st Owner
#             </li>
#             <li>
#              Petrol
#             </li>
#            </ul>
#            <div class="_19zc5">
#             <div class="_2HFRN">
#              <strong>
#               ₹5,083/month
#              </strong>
#             </div>
#             <div class="_7udZZ">
#              <span>
#               ₹228,499
#              </span>
#             </div>
#            </div>
#            <div class="JvSRy">
#             <span class="_3X7mV _2H07I">
#              Zero downpayment
#             </span>
#             <p class="_31Wtw">
#              ₹255,499
#             </p>
#            </div>
#           </div>
#          </a>
#         </div>
#         <div class="col-4">
#          <a class="_9Ue0B" href="https://www.cars24.com/buy-used-Maruti-Dzire-2017-cars-Hyderabad-1043810403/" target="_blank">
#           <div class="align-self-center _2RowP">
#            <div class="_3mZ8j">
#             <span class="lazy-load-image-background blur" style="background-image:;background-size:;display:inline-block">
#              <span class="" style="display:inline-block">
#              </span>
#             </span>
#             <noscript>
#              <img alt="Discount" src="https://www.cars24.com/js/0106f02192c4d92b3a05ecf440d6babc.svg"/>
#             </noscript>
#             ₹
#             <!-- -->
#             21,000
#             <!-- -->
#             OFF
#            </div>
#            <span class="lazy-load-image-background blur" style="background-image:;background-size:;display:inline-block">
#             <span class="_2gVj9" style="display:inline-block">
#             </span>
#            </span>
#            <noscript>
#             <img alt="2017 Maruti Dzire ZDI Plus AMT" class="_2gVj9" src="https://fastly-production.24c.in/hello-ar/dev/uploads/e471de19-9567-410a-a4cb-5fc959a92cf9/cb05ff01-8efd-4b95-a142-c9159aec291e/44.jpg?w=397&amp;auto=format"/>
#            </noscript>
#           </div>
#           <div class="_1l4fi">
#            <div class="_15rKe">
#             <div class="_1jpRU">
#              <h2 class="_3FpCg">
#               2017 Maruti Dzire
#              </h2>
#              <p class="cvakB">
#               ZDI Plus AMT
#               <!-- -->
#               <span>
#                Automatic
#               </span>
#              </p>
#             </div>
#            </div>
#            <ul class="bVR0c">
#             <li>
#              49,145 km
#             </li>
#             <li>
#              1st Owner
#             </li>
#             <li>
#              Diesel
#             </li>
#            </ul>
#            <div class="_19zc5">
#             <div class="_2HFRN">
#              <strong>
#               ₹14,759/month
#              </strong>
#             </div>
#             <div class="_7udZZ">
#              <span>
#               ₹663,499
#              </span>
#             </div>
#            </div>
#            <div class="JvSRy">
#             <span class="_3X7mV _2H07I">
#              Zero downpayment
#             </span>
#             <p class="_31Wtw">
#              ₹684,499
#             </p>
#            </div>
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="_3LGLk">
#        <ul class="pagination">
#         <li class="disabled">
#          <a class="" href="#">
#           <img alt="left" src="https://www.cars24.com/js/6701327798bc95f56e0895cef2262e2e.svg"/>
#          </a>
#         </li>
#         <li class="disabled">
#          <a class="" href="#">
#           Prev
#          </a>
#         </li>
#         <li class="active">
#          <a class="undefined" href="https://www.cars24.com/buy-used-car?sort=P&amp;page=1&amp;storeCityId=3686">
#           1
#          </a>
#         </li>
#         <li class="">
#          <a class="" href="https://www.cars24.com/buy-used-car?sort=P&amp;page=2&amp;storeCityId=3686">
#           2
#          </a>
#         </li>
#         <li class="">
#          <a class="" href="https://www.cars24.com/buy-used-car?sort=P&amp;page=3&amp;storeCityId=3686">
#           3
#          </a>
#         </li>
#         <li class="">
#          <a class="" href="#">
#           Next
#          </a>
#         </li>
#         <li class="">
#          <a class="" href="#">
#           <img alt="right" src="https://www.cars24.com/js/005657cbc1cacb2f5ec8e24a2531f658.svg"/>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="_3AmST">
#      <div class="_3-QJx">
#       <h2 class="_3york">
#        FREQUENTLY ASKED QUESTIONS FOR USED CARS IN HYDERABAD
#       </h2>
#       <div class="row">
#        <div class="col-12">
#         <div class="RpLWp">
#          <h3 class="_2EpwA _32M8V">
#           How many second hand cars are available in Hyderabad?
#           <img src="https://www.cars24.com/js/4c33768dc2869197d8280dbde6ec7ff2.svg" style="transform:rotate(-90deg)"/>
#          </h3>
#          <p class="_36r7-">
#           41 used cars are available in Hyderabad of popular brands like
#           <a href="https://www.cars24.com/buy-used-maruti-cars-hyderabad">
#            Maruti Suzuki
#           </a>
#           ,
#           <a href="https://www.cars24.com/buy-used-hyundai-cars-hyderabad">
#            Hyundai
#           </a>
#           ,
#           <a href="https://www.cars24.com/buy-used-honda-cars-hyderabad">
#            Honda
#           </a>
#           &amp; more
#          </p>
#         </div>
#        </div>
#        <div class="col-12">
#         <div class="RpLWp">
#          <h3 class="_2EpwA">
#           What are the most popular brands available for 2nd hand cars in Hyderabad?
#           <img src="https://www.cars24.com/js/4c33768dc2869197d8280dbde6ec7ff2.svg" style="transform:rotate(90deg)"/>
#          </h3>
#         </div>
#        </div>
#        <div class="col-12">
#         <div class="RpLWp">
#          <h3 class="_2EpwA">
#           What will be the starting price of an old car in Hyderabad?
#           <img src="https://www.cars24.com/js/4c33768dc2869197d8280dbde6ec7ff2.svg" style="transform:rotate(90deg)"/>
#          </h3>
#         </div>
#        </div>
#        <div class="col-12">
#         <div class="RpLWp">
#          <h3 class="_2EpwA">
#           What body types are available for 2nd hand cars in Hyderabad?
#           <img src="https://www.cars24.com/js/4c33768dc2869197d8280dbde6ec7ff2.svg" style="transform:rotate(90deg)"/>
#          </h3>
#         </div>
#        </div>
#        <div class="col-12">
#         <div class="RpLWp">
#          <h3 class="_2EpwA">
#           Can I buy used cars online at CARS24 in Hyderabad?
#           <img src="https://www.cars24.com/js/4c33768dc2869197d8280dbde6ec7ff2.svg" style="transform:rotate(90deg)"/>
#          </h3>
#         </div>
#        </div>
#        <div class="col-12">
#         <div class="RpLWp">
#          <h3 class="_2EpwA">
#           What to check before buying a second hand car in Hyderabad?
#           <img src="https://www.cars24.com/js/4c33768dc2869197d8280dbde6ec7ff2.svg" style="transform:rotate(90deg)"/>
#          </h3>
#         </div>
#        </div>
#        <div class="col-12">
#         <div class="RpLWp">
#          <h3 class="_2EpwA">
#           Where can I buy used cars in Hyderabad?
#           <img src="https://www.cars24.com/js/4c33768dc2869197d8280dbde6ec7ff2.svg" style="transform:rotate(90deg)"/>
#          </h3>
#         </div>
#        </div>
#        <div class="col-12">
#         <div class="RpLWp">
#          <h3 class="_2EpwA">
#           How can I check a second hand car in Hyderabad?
#           <img src="https://www.cars24.com/js/4c33768dc2869197d8280dbde6ec7ff2.svg" style="transform:rotate(90deg)"/>
#          </h3>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div>
#     <footer class="_29ahV">
#      <div class="container">
#       <div class="row">
#        <div class="col col-md-3 col-sm-3 col-xl-3">
#         <h3 class="_3uoXK">
#         </h3>
#         <ul class="YJKn9">
#         </ul>
#         <p class="FstZS">
#          <span>
#           Powered by CARS24
#          </span>
#         </p>
#         <div class="row">
#          <p class="col-12 _671Sy">
#           <span>
#            ®
#            <!-- -->
#            2021
#            <!-- -->
#            www.cars24.com
#           </span>
#           <span>
#            All rights reserved
#           </span>
#          </p>
#         </div>
#        </div>
#        <div class="col col-md-3 col-sm-3 col-xl-3">
#         <h3 class="_3uoXK">
#         </h3>
#         <ul class="mb-2 _34lQt">
#         </ul>
#        </div>
#        <div class="col col-md-6 col-sm-6 col-xl-6">
#         <div class="row">
#          <div class="col">
#           <h3 class="_3uoXK">
#            Top Brands
#           </h3>
#           <ul class="_34lQt">
#           </ul>
#          </div>
#          <div class="col">
#           <h3 class="_3uoXK">
#            TOP CITIES
#           </h3>
#           <ul class="_34lQt">
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="col-12">
#         <h3 class="_3uoXK _1SpUL">
#         </h3>
#         <ul class="_34lQt">
#         </ul>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#    <div class="EGSlO" style="right:40px;bottom:100px">
#     <span>
#      Need Help?
#     </span>
#    </div>
#   </div>
#   <script>
#    window.__PRELOADED_STATE__ = {"brands":{"isSSR":false,"all":[],"popular":[],"error":null},"models":{"isSSR":false,"all":[],"popular":[],"error":null,"isLoading":true},"years":{"data":[],"error":null},"variants":{"data":[],"error":null,"isLoading":true},"registrationStates":{"data":[],"error":null,"isLoading":true},"kilometersDriven":{"isSSR":false,"data":[],"error":null,"apiInProgress":false,"isLoading":true,"whatsappStatus":false},"blogs":{"isSSR":true,"data":[],"error":null},"seoCarOverview":{"isSSR":false,"isFetched":false,"isLoading":true,"content":null,"pageType":null,"seoData":null,"tabs":[],"pageData":null,"isError":false,"noContent":false,"currentSEOSelectedCity":null,"usedCars":[]},"testimonials":{"isSSR":false,"data":[],"error":null},"experts":{"isSSR":false,"data":[],"error":null,"isLoading":true},"faqs":{"isSSR":false,"error":null,"isLoading":true,"order":[],"content":{},"selectedTab":"sell-car","selectedCategorySlug":null,"selectedCategoryID":null,"selectedFAQID":null,"currentTabClicked":null},"recentlyInspected":{"isSSR":false,"dataList":[],"heading":"","insMediaServer":"","error":null},"footer":{"isSSR":false,"data":{},"error":null},"meta":{"home":{"og":{"title":"CARS24 - Sell Your Used Car & Get Paid Instantly | Get Free Car Valuation in India","description":"CARS24  makes your used car selling easy & hassle free. Drive to the nearest CARS24 centre, get free car inspection, sell directly & get paid. ✯Free Car Valuation","url":"https://www.cars24.com/"},"default":{"description":"Buy or sell your car with ease at CARS24. Thousands of quality used cars for sale, delivered to your home. Get the Best Price, Free RC Transfer, in 1 hour when selling a car.","title":"CARS24 - Buy Second Hand Cars Online & Sell Car in 1 Hour"},"canonical":"https://www.cars24.com/"},"seo":{"canonical":"https://www.cars24.com/"},"genericContent":{"heading":"","content":""},"cityImage":{"web":"","mobile":""},"identifiers":{"make":null,"model":null,"city":null,"location":null},"mainHeading":"","templateType":"","isSSR":false,"isFetched":false,"tweets":[]},"news":{"data":[],"error":null,"isSSR":false},"leadData":{"brand":{"displayText":"","id":null},"model":{"displayText":"","id":null},"year":{"displayText":"","id":null,"year_id":null},"fuelType":{"displayText":""},"transmission":{"displayText":""},"registrationState":{"displayText":"","id":null},"variant":{"displayText":"","id":null,"variantType":null},"kilometersDriven":{"displayText":"","id":null},"rto":{"displayText":"","id":null},"branch":{"displayText":"","id":null,"selectionType":"city"},"currentStep":"brand","currentProgressStep":"","currentStepIndex":1,"currentTabIndex":1,"prevTabIndex":0,"proceedCTA":false,"token":null,"error":null,"activateLastStep":false,"priceRange":{},"source":null,"isLeadFormChanged":false,"flowName":"default","ctaLocation":null,"variantActiveScreen":"fueltype"},"seoModels":{"all":[],"popular":[],"isSSR":false,"isLoading":true},"branchLocations":{"branches":[],"selectedValue":null,"selectedID":null,"isLoading":true,"selectionType":"city","selectedBranch":null,"locationIdentifier":1},"cities":{"isSSR":true,"selectedCity":{"id":"3686","name":"Hyderabad"},"error":null,"noData":true,"enableC2CPromotion":false,"isCitySelectionSSR":true},"appointmentLocation":{"locationName":"","placeID":"","selectionType":null,"leadData":null,"error":null},"appointmentDetails":{"zone":null,"locations":[],"slots":null,"selectedInspectionType":null,"selectedBranch":null,"selectedInspectionDate":null,"selectedInspectionTime":null,"isAppointmentCreated":false,"isAppointmentVerified":false,"appointmentID":null,"isEditMode":false,"apiInProgress":false,"isLoading":true,"isFetchingSlots":false,"scrollBottom":false,"checkedStatus":true,"isVerified":false,"prefilledBranch":null,"prefilledInspectionType":null,"sellBikeConsent":false,"isNotServicible":false,"address":null,"landmark":null,"appointmentScreen":"default","appointmentCity":null,"appointmentPincode":null,"previousSelectedZone":nu ...
#   </script>
#   <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">
#    [9,10,192,54]
#   </script>
#   <script data-chunk="desktop" src="https://www.cars24.com/js/desktop.bundle.e47a838b57c6f5070ab0.js">
#   </script>
#   <script data-chunk="pages-desktop-car-listing" src="https://www.cars24.com/js/ce2fb0dc684dde96aa84.vendors~pages-desktop-car-detail~pages-desktop-car-listing~pages-mobile-buy-car~pages-mobile-car-det~84dd9ac7.js">
#   </script>
#   <script data-chunk="pages-desktop-car-listing" src="https://www.cars24.com/js/a4b5fa9e157cf3b5cf20.vendors~pages-desktop-car-detail~pages-desktop-car-listing~pages-desktop-car-loan~pages-desktop-checkout.js">
#   </script>
#   <script data-chunk="pages-desktop-car-listing" src="https://www.cars24.com/js/65768867b6ff335d0ba6.vendors~pages-desktop-car-listing.js">
#   </script>
#   <script data-chunk="pages-desktop-car-listing" src="https://www.cars24.com/js/5b0e575045d98255208e.pages-desktop-car-listing.js">
#   </script>
#   <script>
#    if (window["webappStart"]) window["webappStart"]();
#   </script>
#   <script crossorigin="anonymous" data-cf-beacon='{"rayId":"6b7e3b1e9975e28d","token":"8e8fab7d991544d3b5702c782360d159","version":"2021.11.0","si":100}' defer="" integrity="sha512-gV/bogrUTVP2N3IzTDKzgP0Js1gg4fbwtYB6ftgLbKQu/V8yH2+lrKCfKHelh4SO3DPzKj4/glTO+tNJGDnb0A==" src="https://static.cloudflareinsights.com/beacon.min.js/v64f9daad31f64f81be21cbef6184a5e31634941392597">
#   </script>
#  </body>
# </html>

# %%
# CAR NAME

name = soup.find('h2', attrs={'class' : "_3FpCg"})

print(name.text)
# Out:
# 2009 Mercedes Benz C Class

# %%
# TYPE

type = soup.find('p', attrs={'class' : "cvakB"})

print(type.text)
# Out:
# 220 CDI ELEGANCE AT Automatic

# %%
# DETAILS

details = soup.find('ul', attrs={'class' : "bVR0c"})

print(details.text)
# Out:
# 65,969 km2nd OwnerDiesel

# %%
# PRICE

price = soup.find('div', attrs={'class' : "_7udZZ"})

print(price.text)
# Out:
# ₹928,699

# %%
# EMI

emi = soup.find('div', attrs={'class' : "_2HFRN"})

print(emi.text)
# Out:
# ₹20,658/month

# %%
# DISCOUNT

discount = soup.find('div', attrs={'class' : "_3mZ8j"})

print(discount.text)
# Out:
#  ₹5,000 OFF

# %%
prices = soup.find_all('div', attrs = {'class' : '_7udZZ'})

print(prices)

print(type(prices))

print(type(prices[1]))

for tag in prices:
    print(tag.text)
# Out:
# [<div class="_7udZZ"><span>₹928,699</span></div>, <div class="_7udZZ"><span>₹282,099</span></div>, <div class="_7udZZ"><span>₹407,599</span></div>, <div class="_7udZZ"><span>₹269,099</span></div>, <div class="_7udZZ"><span>₹463,099</span></div>, <div class="_7udZZ"><span>₹303,299</span></div>, <div class="_7udZZ"><span>₹442,099</span></div>, <div class="_7udZZ"><span>₹456,199</span></div>, <div class="_7udZZ"><span>₹290,099</span></div>, <div class="_7udZZ"><span>₹660,899</span></div>, <div class="_7udZZ"><span>₹752,899</span></div>, <div class="_7udZZ"><span>₹305,899</span></div>, <div class="_7udZZ"><span>₹427,999</span></div>, <div class="_7udZZ"><span>₹476,399</span></div>, <div class="_7udZZ"><span>₹431,299</span></div>, <div class="_7udZZ"><span>₹675,699</span></div>, <div class="_7udZZ"><span>₹683,199</span></div>, <div class="_7udZZ"><span>₹1,465,799</span></div>, <div class="_7udZZ"><span>₹228,499</span></div>, <div class="_7udZZ"><span>₹663,499</span></div>]
# []
# []
# ₹928,699
# ₹282,099
# ₹407,599
# ₹269,099
# ₹463,099
# ₹303,299
# ₹442,099
# ₹456,199
# ₹290,099
# ₹660,899
# ₹752,899
# ₹305,899
# ₹427,999
# ₹476,399
# ₹431,299
# ₹675,699
# ₹683,199
# ₹1,465,799
# ₹228,499
# ₹663,499

# %%
for i in range(1, 3):
    print('https://www.cars24.com/buy-used-cars-hyderabad/?itm_source=Cars24Website&itm_medium=sticky_header&page={}'. format(i))
# Out:
# https://www.cars24.com/buy-used-cars-hyderabad/?itm_source=Cars24Website&itm_medium=sticky_header&page=1
# https://www.cars24.com/buy-used-cars-hyderabad/?itm_source=Cars24Website&itm_medium=sticky_header&page=2

# %%
car_prices=[]
# prices
for i in range(2, 3):
    print('https://www.cars24.com/buy-used-cars-hyderabad/?itm_source=Cars24Website&itm_medium=sticky_header&page={}'. format(i))
    prices = soup.find_all('div', attrs={'class' : '_7udZZ'})
    for item in prices:
        if price is None:
            car_prices.append(np.NaN)
        else:
            car_prices.append(price.text)
# Out:
# https://www.cars24.com/buy-used-cars-hyderabad/?itm_source=Cars24Website&itm_medium=sticky_header&page=2

# %%
car_prices
# Out:
# ['₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699',
#  '₹928,699']

# %%
len(car_prices)
# Out:
# 20

# %%
ratings = soup.find_all('div', attrs={'class' : '_3LWZlK'})

# print(ratings)

for tag in ratings:
    print(tag.text)

# %%
url=['https://www.cars24.com/buy-used-cars-hyderabad/?itm_source=Cars24Website&itm_medium=sticky_header',
     'https://www.cars24.com/buy-used-cars-new-delhi/?itm_source=Cars24Website&itm_medium=sticky_header',
    'https://www.cars24.com/buy-used-cars-bengaluru/?itm_source=Cars24Website&itm_medium=sticky_header',
    'https://www.cars24.com/buy-used-car?sort=P&storeCityId=2378&pinId=400001&pinId=400001']

# %%
for i in range(2, 4):
    url.append('https://www.cars24.com/buy-used-cars-hyderabad/?itm_source=Cars24Website&itm_medium=sticky_header&page={}'. format(i))
for i in range(2,9):
    url.append('https://www.cars24.com/buy-used-cars-new-delhi/?itm_source=Cars24Website&itm_medium=sticky_header&page={}'.format(i))
for i in range(2,15):
    url.append('https://www.cars24.com/buy-used-cars-bengaluru/?itm_source=Cars24Website&itm_medium=sticky_header&page={}'.format(i))
for i in range(2,23):
    url.append('https://www.cars24.com/buy-used-car?sort=P&storeCityId=2378&pinId=400001&page={}'.format(i))

# %%
#print(url)

# %%
# %%time

cnames = []
c_type = []
c_details = []
c_price = []
EMI = []
discount = []
location=[]

for i in url:
    
    page = requests.get(URL)
    htmlCode = page.text
    
    soup = BeautifulSoup(htmlCode)
    
    for x in soup.find_all('div', attrs={'class' : 'col-4'}):

        name = x.find('h2', attrs={'class' : '_3FpCg'})
        if name is None:
            cnames.append(np.NaN)
        else:
            cnames.append(name.text)

        c_t = x.find('p', attrs={'class' : 'cvakB'})
        if c_t is None:
            c_type.append(np.NaN)
        else:
            c_type.append(c_t.text)

        details = x.find('ul', attrs={'class' : 'bVR0c'})
        if details is None:
            c_details.append(np.NaN)
        else:
            c_details.append(details.text)

        price = x.find('div', attrs={'class' : '_7udZZ'})
        if price is None:
            c_price.append(np.NaN)
        else:
            c_price.append(price.text)
            
        emi = x.find('div', attrs={'class' : '_2HFRN'})
        if emi is None:
            EMI.append(np.NaN)
        else:
            EMI.append(emi.text)
            
        disc = x.find('div', attrs={'class' : '_3mZ8j'})
        if disc is None:
            discount.append(np.NaN)
        else:
            discount.append(disc.text)
            
        if 'hyderabad' in i:
            location.append('Hyderabad')
        elif 'new-delhi' in i:
            location.append('New Delhi')
        elif 'bengaluru' in i:
            location.append('Bengaluru')
        elif 'CityId=2378' in i:
            location.append('Mumbai')
        else: 
            location.append(np.NaN)
# Out:
# Wall time: 1min

# %%
print(len(cnames))
print(len(c_type))
print(len(c_details))
print(len(c_price))
print(len(EMI))
print(len(discount))
print(len(location))
# Out:
# 1034
# 1034
# 1034
# 1034
# 1034
# 1034
# 1034

# %% [markdown]
# # Creating a DataFrame and saving it in CSV file

# %%
df = pd.DataFrame({'Name' : cnames, 'Type' : c_type, 'Details' : c_details, 'Price' : c_price,'EMI':EMI,'Discount':discount,
                  'Location':location})

# %%
df
# Out:
#                              Name                           Type  \
# 0      2009 Mercedes Benz C Class  220 CDI ELEGANCE AT Automatic
# 1            2015 Maruti Alto K10                     VXI Manual
# 2               2019 Renault Kwid             1.0 RXT Opt Manual
# 3            2015 Maruti Alto 800                     VXI Manual
# 4            2019 Maruti S PRESSO                VXI PLUS Manual
# ...                           ...                            ...
# 1029  2020 Hyundai GRAND I10 NIOS        SPORTZ 1.2 AT Automatic
# 1030            2018 Maruti Dzire                     VDI Manual
# 1031    2019 Toyota Innova Crysta            2.4 GX 8 STR Manual
# 1032             2012 Maruti Alto                     LXI Manual
# 1033            2017 Maruti Dzire         ZDI Plus AMT Automatic
#
#                         Details       Price            EMI      Discount  \
# 0      65,969 km2nd OwnerDiesel    ₹928,699  ₹20,658/month    ₹5,000 OFF
# 1      33,751 km1st OwnerPetrol    ₹282,099   ₹6,275/month   ₹15,000 OFF
# 2      31,559 km1st OwnerPetrol    ₹407,599   ₹9,067/month   ₹27,000 OFF
# 3      47,374 km1st OwnerPetrol    ₹269,099   ₹5,986/month   ₹24,000 OFF
# 4      29,101 km1st OwnerPetrol    ₹463,099  ₹10,301/month   ₹19,000 OFF
# ...                         ...         ...            ...           ...
# 1029   11,947 km1st OwnerPetrol    ₹675,699  ₹15,031/month    ₹5,000 OFF
# 1030   44,932 km1st OwnerDiesel    ₹683,199  ₹15,197/month   ₹29,000 OFF
# 1031  187,298 km1st OwnerDiesel  ₹1,465,799  ₹32,606/month   ₹50,000 OFF
# 1032   21,364 km1st OwnerPetrol    ₹228,499   ₹5,083/month   ₹27,000 OFF
# 1033   49,145 km1st OwnerDiesel    ₹663,499  ₹14,759/month   ₹21,000 OFF
#
#        Location
# 0     Hyderabad
# 1     Hyderabad
# 2     Hyderabad
# 3     Hyderabad
# 4     Hyderabad
# ...         ...
# 1029     Mumbai
# 1030     Mumbai
# 1031     Mumbai
# 1032     Mumbai
# 1033     Mumbai
#
# [1034 rows x 7 columns]

# %%
df
# Out:
#                              Name                           Type  \
# 0      2009 Mercedes Benz C Class  220 CDI ELEGANCE AT Automatic
# 1            2015 Maruti Alto K10                     VXI Manual
# 2               2019 Renault Kwid             1.0 RXT Opt Manual
# 3            2015 Maruti Alto 800                     VXI Manual
# 4            2019 Maruti S PRESSO                VXI PLUS Manual
# ...                           ...                            ...
# 1029  2020 Hyundai GRAND I10 NIOS        SPORTZ 1.2 AT Automatic
# 1030            2018 Maruti Dzire                     VDI Manual
# 1031    2019 Toyota Innova Crysta            2.4 GX 8 STR Manual
# 1032             2012 Maruti Alto                     LXI Manual
# 1033            2017 Maruti Dzire         ZDI Plus AMT Automatic
#
#                         Details       Price            EMI      Discount  \
# 0      65,969 km2nd OwnerDiesel    ₹928,699  ₹20,658/month    ₹5,000 OFF
# 1      33,751 km1st OwnerPetrol    ₹282,099   ₹6,275/month   ₹15,000 OFF
# 2      31,559 km1st OwnerPetrol    ₹407,599   ₹9,067/month   ₹27,000 OFF
# 3      47,374 km1st OwnerPetrol    ₹269,099   ₹5,986/month   ₹24,000 OFF
# 4      29,101 km1st OwnerPetrol    ₹463,099  ₹10,301/month   ₹19,000 OFF
# ...                         ...         ...            ...           ...
# 1029   11,947 km1st OwnerPetrol    ₹675,699  ₹15,031/month    ₹5,000 OFF
# 1030   44,932 km1st OwnerDiesel    ₹683,199  ₹15,197/month   ₹29,000 OFF
# 1031  187,298 km1st OwnerDiesel  ₹1,465,799  ₹32,606/month   ₹50,000 OFF
# 1032   21,364 km1st OwnerPetrol    ₹228,499   ₹5,083/month   ₹27,000 OFF
# 1033   49,145 km1st OwnerDiesel    ₹663,499  ₹14,759/month   ₹21,000 OFF
#
#        Location
# 0     Hyderabad
# 1     Hyderabad
# 2     Hyderabad
# 3     Hyderabad
# 4     Hyderabad
# ...         ...
# 1029     Mumbai
# 1030     Mumbai
# 1031     Mumbai
# 1032     Mumbai
# 1033     Mumbai
#
# [1034 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      940 non-null    object
#  1   Type      940 non-null    object
#  2   Details   940 non-null    object
#  3   Price     940 non-null    object
#  4   EMI       940 non-null    object
#  5   Discount  940 non-null    object
#  6   Location  1034 non-null   object
# dtypes: object(7)
# memory usage: 56.7+ KB

# %%
df['Name'].value_counts()
# Out:
# 2017 Maruti Alto 800           94
# 2015 Maruti Alto K10           94
# 2019 Maruti Eeco               94
# 2015 Maruti Alto 800           47
# 2019 Toyota Innova Crysta      47
# 2020 Hyundai GRAND I10 NIOS    47
# 2009 Mercedes Benz C Class     47
# 2018 Maruti Dzire              47
# 2016 Hyundai Grand i10         47
# 2018 Hyundai Elite i20         47
# 2019 Renault Kwid              47
# 2012 Maruti Alto               47
# 2019 Hyundai NEW SANTRO        47
# 2015 Hyundai Grand i10         47
# 2017 Hyundai Elite i20         47
# 2017 Maruti Dzire              47
# 2019 Maruti S PRESSO           47
# Name: Name, dtype: int64

# %%
df['Name'] = df['Name'].fillna(0)

# %%
df['Name'].value_counts()
# Out:
# 0                              94
# 2015 Maruti Alto K10           94
# 2019 Maruti Eeco               94
# 2017 Maruti Alto 800           94
# 2017 Maruti Dzire              47
# 2017 Hyundai Elite i20         47
# 2015 Hyundai Grand i10         47
# 2012 Maruti Alto               47
# 2019 Hyundai NEW SANTRO        47
# 2018 Hyundai Elite i20         47
# 2019 Renault Kwid              47
# 2015 Maruti Alto 800           47
# 2016 Hyundai Grand i10         47
# 2018 Maruti Dzire              47
# 2009 Mercedes Benz C Class     47
# 2020 Hyundai GRAND I10 NIOS    47
# 2019 Toyota Innova Crysta      47
# 2019 Maruti S PRESSO           47
# Name: Name, dtype: int64

# %%
# a=[]

# for i in df['Name'] :
#     if i == 0:
#         a.append(0)
#     else:
#         a.append(i.split()[0])
# df['Year'] = a

# b=[]

# for i in df['Name'] :
#     if i == 0:
#         b.append(0)
#     else:
#         b.append(i.split()[1])
# df['Brand'] = b

# c=[]
# for i in df['Name'] :
#     if i == 0:
#         c.append(0)
#     else:
#         c.append(i.split()[2:]

# df['Model']=c

# %%
import re
regex = r'\d+\s'

df['Year'] = df['Name'].apply(lambda x : re.findall(regex, x) if x!=0 else ["2012"])
df.Year = df.Year.apply(lambda x: "".join(x))

# %%
df.Year.value_counts()
# Out:
# 2019        282
# 2017        188
# 2015        188
# 2012         94
# 2018         94
# 2020 10      47
# 2012         47
# 2016         47
# 2009         47
# Name: Year, dtype: int64

# %%
regex = r'(?:Maruti|Hyundai|Toyota|Renault| Mercedes)'
df['Brand'] = df.Name.apply(lambda x : re.findall(regex,x) if x!=0 else ["None"])
df.Brand = df.Brand.apply(lambda x: "".join(x))

# %%
df.Brand.value_counts()
# Out:
# Maruti       517
# Hyundai      282
# None          94
#  Mercedes     47
# Toyota        47
# Renault       47
# Name: Brand, dtype: int64

# %%
c=[]
for i in df['Name'] :
    if i == 0:
        c.append(0)
    else:
        c.append(i.split()[2:])

# %%
#c

# %%
df['Model']=c
df.Model = df.Model.apply(lambda x: " ".join(x) if x!=0 else "None")

# %%
df.Model.value_counts()
# Out:
# Alto 800          141
# None               94
# Alto K10           94
# Grand i10          94
# Eeco               94
# Elite i20          94
# Dzire              94
# S PRESSO           47
# NEW SANTRO         47
# GRAND I10 NIOS     47
# Benz C Class       47
# Alto               47
# Innova Crysta      47
# Kwid               47
# Name: Model, dtype: int64

# %%
df.Type.value_counts()
# Out:
# VXI Manual                       141
# LXI Manual                        94
# 5 STR WITH AC PLUSHTR Manual      94
# 220 CDI ELEGANCE AT Automatic     47
# SPORTZ 1.2 AT Automatic           47
# ASTA 1.2 AT                       47
# VXI PLUS Manual                   47
# VDI Manual                        47
# ZDI Plus AMT Automatic            47
# 1.0 RXT Opt Manual                47
# ASTA 1.2 (O) Manual               47
# 2.4 GX 8 STR Manual               47
# 1.1 SPORTS MT CNG                 47
# MAGNA 1.2 VTVT Manual             47
# LXI OPT Manual                    47
# SPORTS 1.2 VTVT Manual            47
# Name: Type, dtype: int64

# %%
df['Type'] = df['Type'].fillna(0)

# %%
regex = r'(?:Manual|Automatic)'
df['car_type'] = df.Type.apply(lambda x : re.findall(regex,x) if x!=0 else "None")
df.car_type = df.car_type.apply(lambda x: "".join(x))

# %%
df.car_type
# Out:
# 0       Automatic
# 1          Manual
# 2          Manual
# 3          Manual
# 4          Manual
#           ...
# 1029    Automatic
# 1030       Manual
# 1031       Manual
# 1032       Manual
# 1033    Automatic
# Name: car_type, Length: 1034, dtype: object

# %%
df['Type'].replace(to_replace=["Manual","Automatic"],value="",inplace=True,regex=True)

# %%
df.Type
# Out:
# 0       220 CDI ELEGANCE AT
# 1                       VXI
# 2               1.0 RXT Opt
# 3                       VXI
# 4                  VXI PLUS
#                 ...
# 1029          SPORTZ 1.2 AT
# 1030                    VDI
# 1031           2.4 GX 8 STR
# 1032                    LXI
# 1033           ZDI Plus AMT
# Name: Type, Length: 1034, dtype: object

# %%
df.Details.value_counts()
# Out:
# 49,145 km1st OwnerDiesel          47
# 65,969 km2nd OwnerDiesel          47
# 26,729 km2nd OwnerPetrol          47
# 11,900 km1st OwnerPetrol          47
# 33,751 km1st OwnerPetrol          47
# 187,298 km1st OwnerDiesel         47
# 20,001 km1st OwnerPetrol          47
# 21,364 km1st OwnerPetrol          47
# 63,674 km1st OwnerPetrol          47
# 47,374 km1st OwnerPetrol          47
# 44,932 km1st OwnerDiesel          47
# 29,101 km1st OwnerPetrol          47
# 11,947 km1st OwnerPetrol          47
# 35,080 km1st OwnerPetrol          47
# 34,590 km2nd OwnerPetrol          47
# 9,338 km2nd OwnerPetrol           47
# 31,559 km1st OwnerPetrol          47
# 30,557 km1st OwnerPetrol          47
# 20,768 km1st OwnerPetrol          47
# 36,126 km1st OwnerPetrol + CNG    47
# Name: Details, dtype: int64

# %%
df['Details'] = df['Details'].fillna(0)

# %%
regex = r'([,\d]+\skm)'
df['km'] = df.Details.apply(lambda x : re.findall(regex,x) if x!=0 else "None")
df.km = df.km.apply(lambda x: "".join(x))
df['km'].replace(to_replace="km",value="",inplace=True,regex=True)

# %%
df.km.value_counts()
# Out:
# None        94
# 29,101      47
# 21,364      47
# 35,080      47
# 34,590      47
# 65,969      47
# 63,674      47
# 47,374      47
# 36,126      47
# 11,947      47
# 30,557      47
# 33,751      47
# 49,145      47
# 26,729      47
# 11,900      47
# 44,932      47
# 20,001      47
# 20,768      47
# 187,298     47
# 9,338       47
# 31,559      47
# Name: km, dtype: int64

# %%
#df.dropna(axis=0,how="all",inplace=True)

# %%
#df.isnull().sum()

# %%
regex = r'(?:1st|2nd)'
df['owner'] = df.Details.apply(lambda x : re.findall(regex,x) if x!=0 else "None")
df.owner = df.owner.apply(lambda x: "".join(x))
df['owner'].replace(to_replace=["st","nd"],value="",inplace=True,regex=True)

# %%
regex = r'(?:Petrol|Diesel)'
df['fuel'] = df.Details.apply(lambda x : re.findall(regex,x) if x!=0 else "None")
df.fuel = df.fuel.apply(lambda x: "".join(x))

# %%
df.drop(["Name","Details"],axis=1,inplace=True)

# %%
df['Price'].replace(to_replace=["₹",","],value="",inplace=True,regex=True)
df['Price'] = df['Price'].fillna(0)
df.Price=df.Price.astype(int)
df['Price'].fillna(df['Price'].median(), inplace=True)
df['Price'].isnull().sum()
# Out:
# 0

# %%
df['EMI'].replace(to_replace=["₹",",","/month"],value="",inplace=True,regex=True)
df['EMI'] = df['EMI'].fillna(0)
df.EMI=df.Price.astype(int)
df['EMI'].fillna(df['EMI'].median(), inplace=True)
df['EMI'].isnull().sum()
# Out:
# 0

# %%
df['Discount'].replace(to_replace=["₹",",","OFF"],value="",inplace=True,regex=True)
df['Discount'] = df['Discount'].fillna(0)
df.Discount=df.Price.astype(int)
df['Discount'].fillna(df['Discount'].median(), inplace=True)
df['Discount'].isnull().sum()
# Out:
# 0
